# %% [markdown]
# # Importing datasets from github
#
# To import any dataset from github do the following steps -
# 1. Search for the dataset you want on github.
# 2. Once you are on the page of your desired datset click on the RAW tab on the screen. as shown below -

# %%
from IPython.display import Image
Image("c1.PNG")

# %% [markdown]
# 3. Copy the URL and store it in variable named URL (demonstrated in this notebook).
# 4. Now use this URL in your notebook directly. as shown below -

# %% [markdown]
# ## Dataset 1: Bene_insurance.csv

# %%
import pandas as pd
URL = "https://raw.githubusercontent.com/DSpython/importing_datasets/master/Datasets/Bene_insurance.csv"
df = pd.read_csv(URL)
df.head(2)
# Out:
#    BenefUserID BenefPriID BenefRelToPriID  BenefPolID    BenefDOB BenefSex  \
# 0          702    PID-176         Brother          18  18/01/1983        F
# 1         2301   PID-1070         Husband           2    7/1/2008        F
#
#    BenefPremium  BenefActive
# 0          9648            0
# 1          5490            0

# %% [markdown]
# ## Dataset 2: Claim_insurance.csv

# %%
import pandas as pd
URL = "https://raw.githubusercontent.com/DSpython/importing_datasets/master/Datasets/Claim_insurance.csv"
df = pd.read_csv(URL)
df.head(2)
# Out:
#    BenefUserID  ClmAmount                 Clmdoa                 Clmdod  \
# 0          108      20133  30AUG2008:12:00:00 AM  07SEP2008:12:00:00 AM
# 1          114      37000  18DEC2008:12:00:00 AM  18DEC2008:12:00:00 AM
#
#    ClmApprovedamt StatusName                    AilmentName AilmentCode  \
# 0         17121.0    Settled   Internal derangement of knee         M23
# 1         28080.0    Settled  Senile cataract LE (Left Eye)         H26
#
#          TreatmentName CityName     HospId
# 0  Surgical Management  Chennai  HopID-523
# 1             Cataract   Mumbai  HopID-279

# %% [markdown]
# ## Dataset 3: Patient treatment trns.csv

# %%
import pandas as pd
URL = "https://raw.githubusercontent.com/DSpython/importing_datasets/master/Datasets/Patient%20treatment%20trns.csv"
df = pd.read_csv(URL)
df.head(2)
# Out:
#   Patient Treatment      Spend
# 0      P1        T1   $422.00
# 1      P1        T2   $512.00

# %% [markdown]
# ## Dataset 4: Sample_data.csv

# %%
import pandas as pd
URL = "https://raw.githubusercontent.com/DSpython/importing_datasets/master/Datasets/Sample_data.csv"
df = pd.read_csv(URL)
df.head(2)
# Out:
#     ID  Gender  Race  SEB  School  Prog  Read  Write  Math1  Math2  SST
# 0   70       0     4    1       1     1    57     52     41     47   57
# 1  121       1     4    2       1     3    68     59     53     63   61

# %% [markdown]
# ## Dataset 5: matches.csv

# %%
import pandas as pd
URL = "https://raw.githubusercontent.com/DSpython/importing_datasets/master/Datasets/matches.csv"
df = pd.read_csv(URL)
df.head(2)
# Out:
#    id  season       city      date                team1  \
# 0   1    2017  Hyderabad  05/04/17  Sunrisers Hyderabad
# 1   2    2017       Pune  06/04/17       Mumbai Indians
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
#
#   player_of_match                                      venue         umpire1  \
# 0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal     AY Dandekar
# 1       SPD Smith    Maharashtra Cricket Association Stadium  A Nand Kishore
#
#     umpire2  umpire3
# 0  NJ Llong      NaN
# 1    S Ravi      NaN
